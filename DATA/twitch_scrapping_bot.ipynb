# %% [markdown]
# **Article :**
# https://www.learndatasci.com/tutorials/how-stream-text-data-twitch-sockets-python/m

# %% [markdown]
# # Twitch Scrapping Bot

# %% [markdown]
# Get the notebook and scripts for this article on :
# https://github.com/LearnDataSci/articles/tree/master/How%20to%20Stream%20Text%20Data%20from%20Twitch%20with%20Sockets%20in%20Python
#
# #### Getting your credentials
#
# Go to https://twitchapps.com/tmi/ to request an auth token for your Twitch account. You'll need to click "Connect with Twitch" and "Authorize" to produce a token
#
# **channel** corresponds to the streamer's name and can be the name of any channel you're interested in

# %%
server = 'irc.chat.twitch.tv'
port = 6667
nickname = 'mck_ix'
token = 'oauth:ltnrj0wblnumqh17kjgckqu6v60arp'
channel = '#ponce'

# %% [markdown]
# #### Connecting to Twitch with sockets
# To establish a connection to Twitch IRC we'll be using Python's socket library. First we need to instantiate a socket:

# %%
import socket
sock = socket.socket()
sock.connect((server, port))

# %% [markdown]
# - PASS carries our token
# - NICK carries our username
# - JOIN carries the channel
#
# Note that we send encoded strings by calling .encode('utf-8'). This encodes the string into bytes which allows it to be sent over the socket.

# %%
sock.send(f"PASS {token}\n".encode('utf-8'))
sock.send(f"NICK {nickname}\n".encode('utf-8'))
sock.send(f"JOIN {channel}\n".encode('utf-8'))
# Out:
# 12

# %% [markdown]
# **Receiving channel messages**
#
# Now we have successfully connected and can receive responses from the channel we subscribed to. To get a single response we can call **.recv()** and then decode the message from bytes:

# %%
resp = sock.recv(2048).decode('utf-8')

resp
# Out:
# ':tmi.twitch.tv 001 mck_ix :Welcome, GLHF!\r\n:tmi.twitch.tv 002 mck_ix :Your host is tmi.twitch.tv\r\n:tmi.twitch.tv 003 mck_ix :This server is rather new\r\n:tmi.twitch.tv 004 mck_ix :-\r\n:tmi.twitch.tv 375 mck_ix :-\r\n:tmi.twitch.tv 372 mck_ix :You are in a maze of twisty passages, all alike.\r\n:tmi.twitch.tv 376 mck_ix :>\r\nPING :tmi.twitch.tv\r\n'

# %%
resp = sock.recv(2048).decode('utf-8')

resp
# Out:
# ':huranthil!huranthil@huranthil.tmi.twitch.tv PRIVMSG #ponce :Mais Wingo il se défend de ouf ? Quel crack haha ponceOVERTOAD\r\n:randoche!randoche@randoche.tmi.twitch.tv PRIVMSG #ponce :GEOZONE\r\n'

# %%
# sock.close()

# %% [markdown]
# #### Writing messages to a file

# %%
import logging

logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s — %(message)s',
                    datefmt='%Y-%m-%d_%H:%M:%S',
                    handlers=[logging.FileHandler('chat.log', encoding='utf-8')])

# %%
logging.info(resp)

# %% [markdown]
# #### Continuous message writing

# %%
from emoji import demojize

# %%
while True:
    resp = sock.recv(2048).decode('utf-8')

    if resp.startswith('PING'):
        sock.send("PONG\n".encode('utf-8'))
    
    elif len(resp) > 0:
        logging.info(demojize(resp))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-ddd15e0773d9> in <module>
#       1 while True:
# ----> 2     resp = sock.recv(2048).decode('utf-8')
#       3
#       4     if resp.startswith('PING'):
#       5         sock.send("PONG\n".encode('utf-8'))
#
# KeyboardInterrupt:

# %% [markdown]
# #### Parsing logs

# %%
msg = '2018-12-10_11:26:40 — :spappygram!spappygram@spappygram.tmi.twitch.tv PRIVMSG #ninja :Chat, let Ninja play solos'

# %%
from datetime import datetime

time_logged = msg.split()[0].strip()

time_logged = datetime.strptime(time_logged, '%Y-%m-%d_%H:%M:%S')

time_logged
# Out:
# datetime.datetime(2018, 12, 10, 11, 26, 40)

# %%
username_message = msg.split('—')[1:]
username_message = '—'.join(username_message).strip()

username_message
# Out:
# ':spappygram!spappygram@spappygram.tmi.twitch.tv PRIVMSG #ninja :Chat, let Ninja play solos'

# %%
import re

username, channel, message = re.search(':(.*)\!.*@.*\.tmi\.twitch\.tv PRIVMSG #(.*) :(.*)', username_message).groups()

print(f"Channel: {channel} \nUsername: {username} \nMessage: {message}")
# Out:
# Channel: ninja
# Username: spappygram
# Message: Chat, let Ninja play solos

# %%
import pandas as pd

def get_chat_dataframe(file):
    data = []

    with open(file, 'r', encoding='utf-8') as f:
        lines = f.read().split('\n\n\n')
        
        for line in lines:
            try:
                time_logged = line.split('—')[0].strip()
                time_logged = datetime.strptime(time_logged, '%Y-%m-%d_%H:%M:%S')

                username_message = line.split('—')[1:]
                username_message = '—'.join(username_message).strip()

                username, channel, message = re.search(
                    ':(.*)\!.*@.*\.tmi\.twitch\.tv PRIVMSG #(.*) :(.*)', username_message
                ).groups()

                d = {
                    'dt': time_logged,
                    'channel': channel,
                    'username': username,
                    'message': message
                }

                data.append(d)
            
            except Exception:
                pass
            
    return pd.DataFrame().from_records(data)
        
    
df = get_chat_dataframe('chat.log')

# %%
df.set_index('dt', inplace=True)

print(df.shape)

df.head()
# Out:
# (56, 3)
#                     channel         username  \
# dt
# 2022-03-18 14:28:40   ponce  lesaumonparfait
# 2022-03-18 14:32:19   ponce         eri_keii
# 2022-03-18 14:32:21   ponce           spyhna
# 2022-03-18 14:32:22   ponce          raizie_
# 2022-03-18 14:32:24   ponce          hyoukho
#
#                                                                message
# dt
# 2022-03-18 14:28:40  ponceFLEUR ponceFLEUR ponceFLEUR ponceFLEUR po...
# 2022-03-18 14:32:19  Bonjour à toutes les belles fleurs ponceCOEURF...
# 2022-03-18 14:32:21  @afternoune omg j'viens de capter que mon 05 c...
# 2022-03-18 14:32:22                                              wooow
# 2022-03-18 14:32:24                                         ponceBLEUE

# %%
df
# Out:
#                     channel              username  \
# dt
# 2022-03-18 14:28:40   ponce       lesaumonparfait
# 2022-03-18 14:32:19   ponce              eri_keii
# 2022-03-18 14:32:21   ponce                spyhna
# 2022-03-18 14:32:22   ponce               raizie_
# 2022-03-18 14:32:24   ponce               hyoukho
# 2022-03-18 14:32:24   ponce               saylux_
# 2022-03-18 14:32:25   ponce             bblackmc_
# 2022-03-18 14:32:26   ponce             cyrial_42
# 2022-03-18 14:32:28   ponce          goldengameon
# 2022-03-18 14:32:30   ponce    thestrangiatobytor
# 2022-03-18 14:32:32   ponce             th_aytrix
# 2022-03-18 14:32:33   ponce              flames59
# 2022-03-18 14:32:34   ponce              eivalf27
# 2022-03-18 14:32:34   ponce               zweatms
# 2022-03-18 14:32:35   ponce                gleg__
# 2022-03-18 14:32:40   ponce              neo_joly
# 2022-03-18 14:32:41   ponce              artus711
# 2022-03-18 14:32:43   ponce               emmae15
# 2022-03-18 14:32:44   ponce               maechi_
# 2022-03-18 14:32:44   ponce             abcdebile
# 2022-03-18 14:32:46   ponce               nairo34
# 2022-03-18 14:32:47   ponce              flokijtv
# 2022-03-18 14:32:48   ponce              bapthard
# 2022-03-18 14:32:48   ponce                siullo
# 2022-03-18 14:32:49   ponce             cyrial_42
# 2022-03-18 14:32:50   ponce            afternoune
# 2022-03-18 14:32:50   ponce        mimosa_etoilee
# 2022-03-18 14:32:51   ponce              flames59
# 2022-03-18 14:32:51   ponce               luleza_
# 2022-03-18 14:32:51   ponce               maechi_
# 2022-03-18 14:32:56   ponce          terrorking97
# 2022-03-18 14:32:56   ponce               maechi_
# 2022-03-18 14:32:57   ponce               emmae15
# 2022-03-18 14:32:58   ponce  tontonmarcelofficiel
# 2022-03-18 14:32:59   ponce               ossrox_
# 2022-03-18 14:33:00   ponce               zweatms
# 2022-03-18 14:33:01   ponce                naryoh
# 2022-03-18 14:33:02   ponce             gregoiire
# 2022-03-18 14:33:03   ponce          wired_layers
# 2022-03-18 14:33:03   ponce                moobot
# 2022-03-18 14:33:05   ponce                ne0sam
# 2022-03-18 14:33:11   ponce                hika65
# 2022-03-18 14:33:13   ponce             heartmoon
# 2022-03-18 14:33:13   ponce             tony_du57
# 2022-03-18 14:33:41   ponce             huranthil
# 2022-03-18 14:33:42   ponce             gregoiire
# 2022-03-18 14:33:46   ponce               prmdboy
# 2022-03-18 14:33:46   ponce              ellana__
# 2022-03-18 14:33:47   ponce          monstre_smm2
# 2022-03-18 14:33:49   ponce              i_hera_i
# 2022-03-18 14:33:49   ponce         renardpatient
# 2022-03-18 14:33:50   ponce          fiashforward
# 2022-03-18 14:33:50   ponce              flokijtv
# 2022-03-18 14:33:51   ponce              flames59
# 2022-03-18 14:33:51   ponce             cyrial_42
# 2022-03-18 14:33:54   ponce               maze_83
#
#                                                                message
# dt
# 2022-03-18 14:28:40  ponceFLEUR ponceFLEUR ponceFLEUR ponceFLEUR po...
# 2022-03-18 14:32:19  Bonjour à toutes les belles fleurs ponceCOEURF...
# 2022-03-18 14:32:21  @afternoune omg j'viens de capter que mon 05 c...
# 2022-03-18 14:32:22                                              wooow
# 2022-03-18 14:32:24                                         ponceBLEUE
# 2022-03-18 14:32:24                                Tu rides la peuf la
# 2022-03-18 14:32:25                                                LUL
# 2022-03-18 14:32:26                                                LUL
# 2022-03-18 14:32:28                                         ponceBLEUE
# 2022-03-18 14:32:30                                            LUL LUL
# 2022-03-18 14:32:32                                      du coup il ya
# 2022-03-18 14:32:33  ponceFLEUR ponceFLEUR ponceFLEUR ponceFLEUR po...
# 2022-03-18 14:32:34     @Ne0sam yo bg ponceHIF ponceCOEURF ponceGOUTTE
# 2022-03-18 14:32:34                                                LUL
# 2022-03-18 14:32:35  Salut les bg je regarde pas hyper souvent su m...
# 2022-03-18 14:32:40  d'ailleurs on voit le bateau de Voie Céleste a...
# 2022-03-18 14:32:41  @misterdrif attends comment ça raysu est dans ...
# 2022-03-18 14:32:43                @Ne0sam salut! etoilesBg ponceCOEUR
# 2022-03-18 14:32:44                                  @Gleg__ Non 150 !
# 2022-03-18 14:32:44                                               ouch
# 2022-03-18 14:32:46  J'aime pas du tout cette map perso. J'ai l'imp...
# 2022-03-18 14:32:47                                                LUL
# 2022-03-18 14:32:48                                            L'échec
# 2022-03-18 14:32:48                                                LUL
# 2022-03-18 14:32:49                                            LUL LUL
# 2022-03-18 14:32:50                    @Spyhna mdrrrr y'a R ponceCOEUR
# 2022-03-18 14:32:50                                                LUL
# 2022-03-18 14:32:51                                                LUL
# 2022-03-18 14:32:51                                    LUL LUL LUL LUL
# 2022-03-18 14:32:51                                                LUL
# 2022-03-18 14:32:56  Waluigi quand il fait une figure on dirait qu'...
# 2022-03-18 14:32:56                                         Bien tenté
# 2022-03-18 14:32:57                                                LUL
# 2022-03-18 14:32:58  Ont a un lobby pour découvrir les nouvelles ma...
# 2022-03-18 14:32:59                              OMG LA STRAT PogChamp
# 2022-03-18 14:33:00                                        LA DINGZZZZ
# 2022-03-18 14:33:01                 C'était sur GBA ce circuit non ?!!
# 2022-03-18 14:33:02                                           Yeaaah !
# 2022-03-18 14:33:03                                             !dlcmk
# 2022-03-18 14:33:03  @wired_layers 8 Nouvelles maps sont disponible...
# 2022-03-18 14:33:05  OMG eivalf27 la bg ultime etoilesLove ne0samLo...
# 2022-03-18 14:33:11  @gleg__, je dirai que les nouvelles maps force...
# 2022-03-18 14:33:13  Il y a moyen que l'ampleur du rebond diffère e...
# 2022-03-18 14:33:13  il y aurait pas un cut avec le deltaplane a la...
# 2022-03-18 14:33:41  Mais Wingo il se défend de ouf ? Quel crack ha...
# 2022-03-18 14:33:42  @Ponce Play est dans la room ? Car je peux partir
# 2022-03-18 14:33:46                                                 ok
# 2022-03-18 14:33:46           J'ai des bugs reguliers, c'est que moi ?
# 2022-03-18 14:33:47                                   c'est un salon ?
# 2022-03-18 14:33:49  ponceGGF ponceGGF ponceGGF ponceGGF ponceGGF p...
# 2022-03-18 14:33:49                y a un cut de fou au début je crois
# 2022-03-18 14:33:50                              Si ça prend le random
# 2022-03-18 14:33:50                                                 nk
# 2022-03-18 14:33:51                               Let's goo le coach !
# 2022-03-18 14:33:51                Merci ceux qui ont leave ponceCOEUR
# 2022-03-18 14:33:54  Les nouvelles map vont rebattre un peu les car...

# %%
df.iloc[0:10,:]
# Out:
#                     channel            username  \
# dt
# 2022-03-18 14:28:40   ponce     lesaumonparfait
# 2022-03-18 14:32:19   ponce            eri_keii
# 2022-03-18 14:32:21   ponce              spyhna
# 2022-03-18 14:32:22   ponce             raizie_
# 2022-03-18 14:32:24   ponce             hyoukho
# 2022-03-18 14:32:24   ponce             saylux_
# 2022-03-18 14:32:25   ponce           bblackmc_
# 2022-03-18 14:32:26   ponce           cyrial_42
# 2022-03-18 14:32:28   ponce        goldengameon
# 2022-03-18 14:32:30   ponce  thestrangiatobytor
#
#                                                                message
# dt
# 2022-03-18 14:28:40  ponceFLEUR ponceFLEUR ponceFLEUR ponceFLEUR po...
# 2022-03-18 14:32:19  Bonjour à toutes les belles fleurs ponceCOEURF...
# 2022-03-18 14:32:21  @afternoune omg j'viens de capter que mon 05 c...
# 2022-03-18 14:32:22                                              wooow
# 2022-03-18 14:32:24                                         ponceBLEUE
# 2022-03-18 14:32:24                                Tu rides la peuf la
# 2022-03-18 14:32:25                                                LUL
# 2022-03-18 14:32:26                                                LUL
# 2022-03-18 14:32:28                                         ponceBLEUE
# 2022-03-18 14:32:30                                            LUL LUL

# %%
df.iloc[0:10,1:3]
# Out:
#                                username  \
# dt
# 2022-03-18 14:28:40     lesaumonparfait
# 2022-03-18 14:32:19            eri_keii
# 2022-03-18 14:32:21              spyhna
# 2022-03-18 14:32:22             raizie_
# 2022-03-18 14:32:24             hyoukho
# 2022-03-18 14:32:24             saylux_
# 2022-03-18 14:32:25           bblackmc_
# 2022-03-18 14:32:26           cyrial_42
# 2022-03-18 14:32:28        goldengameon
# 2022-03-18 14:32:30  thestrangiatobytor
#
#                                                                message
# dt
# 2022-03-18 14:28:40  ponceFLEUR ponceFLEUR ponceFLEUR ponceFLEUR po...
# 2022-03-18 14:32:19  Bonjour à toutes les belles fleurs ponceCOEURF...
# 2022-03-18 14:32:21  @afternoune omg j'viens de capter que mon 05 c...
# 2022-03-18 14:32:22                                              wooow
# 2022-03-18 14:32:24                                         ponceBLEUE
# 2022-03-18 14:32:24                                Tu rides la peuf la
# 2022-03-18 14:32:25                                                LUL
# 2022-03-18 14:32:26                                                LUL
# 2022-03-18 14:32:28                                         ponceBLEUE
# 2022-03-18 14:32:30                                            LUL LUL

# %%
msg_01 = "EP 1"

motif = re.compile("1")
obj = motif.search(msg_01)
if obj:
    print('Trouvée')
else:
    print ('Non Trouvée')
# Out:
# Trouvée

# %%
msg_01 = "Naruto Shippuden"
msg_02 = "Naruto"

# %%
def hamming_distance(string1, string2): 
    if (len(string1) != len (string2)):
        return -1
    # Start with a distance of zero, and count up
    distance = 0
    # Loop over the indices of the string
    L = len(string1)
    for i in range(L):
        # Add 1 to the distance if these two characters are not equal
        if string1[i] != string2[i]:
            distance += 1
    # Return the final count of differences
    return distance
 
hamming_distance(msg_01, msg_02)
# Out:
# -1

# %%
import jaro
jaro.jaro_metric(msg_01, msg_02)
# Out:
# 0.7916666666666666

# %%
import Levenshtein as lev

# %%
def levCalclulate(str1, str2):
    Distance = lev.distance(str1, str2)
    Ratio = lev.ratio(str1, str2)
#     print("Levenshtein entre {0} et {1}".format(str1, str2))
#     print("> Distance: {0}\n> Ratio: {1}\n".format(Distance, Ratio))
    return Distance, Ratio

# levCalclulate("Benoit", "Ben")
# levCalclulate("Benoit", "Benoist")
# levCalclulate(msg_01, msg_02)

# %%
msg_01 = "naruto shippuden"
msg_02 = "Narut shipouden".lower()

levCalclulate(msg_01, msg_02)
# Out:
# Levenshtein entre naruto Shippuden et narut shipouden
# > Distance: 3
# > Ratio: 0.8387096774193549

# %% [markdown]
# #### TEST BDD EXCEL

# %%
bdd_01 = pd.read_excel(r'BDD\bdd_01.xlsx')

# %%
bdd_01
# Out:
#    Série  Question Catégorie        Titre du son         Nom de l'oeuvre  \
# 0      1         1     Anime             Unravel             Tokyo Ghoul
# 1      1         2     Anime           The World              Death Note
# 2      1         3     Anime                Sign        Naruto Shippuden
# 3      1         4     Anime  CHA-LA HEAD CHA-LA           Dragon Ball Z
# 4      1         5     Anime          Departure!  Hunter x Hunter (2011)
#
#   Type du son (EP,ED,OST)  Numéro du son      Auteur du son
# 0                      OP              1      Toru Kitajima
# 1                      OP              1         NIGHTMARE
# 2                      OP              6               Flow
# 3                      OP              1  Kageyama Hironobu
# 4                      OP              1      Ono Masatoshi

# %%
def remove_all_extra_spaces(string):
    return " ".join(string.split())

# %%
bdd_01_lower = bdd_01.apply(lambda x: x.astype(str).str.lower())

# %%
msg_01 = "Unravel / Tokyo Ghoul / OP/ 1/ Toru Kitajima"
msg_01 = msg_01.lower()
msg_01_liste = msg_01.split("/")
msg_01_clean = msg_01_liste

# %%
for index, elem in enumerate(msg_01_liste):
    if isinstance(elem, str) == True:
        msg_01_clean[index] = remove_all_extra_spaces(elem)
    else:
        msg_01_clean[index] = elem
    
msg_01_clean
# Out:
# ['unravel', 'tokyo ghoul', 'op', '1', 'toru kitajima']

# %%
bdd_01_lower.iloc[0][3]
# Out:
# 'unravel'

# %%
bdd_01_score = pd.read_excel(r'BDD\bdd_score.xlsx')

# %%
bdd_01_score
# Out:
#     Username  Série  Question  Titre du son (+1)  Nom de l'oeuvre (+3)  \
# 0     MCK_IX      1         1                NaN                   NaN
# 1     MCK_IX      1         2                NaN                   NaN
# 2     MCK_IX      1         3                NaN                   NaN
# 3     MCK_IX      1         4                NaN                   NaN
# 4     MCK_IX      1         5                NaN                   NaN
# 5   aypepito      1         1                NaN                   NaN
# 6   aypepito      1         2                NaN                   NaN
# 7   aypepito      1         3                NaN                   NaN
# 8   aypepito      1         4                NaN                   NaN
# 9   aypepito      1         5                NaN                   NaN
# 10    bleatz      1         1                NaN                   NaN
# 11    bleatz      1         2                NaN                   NaN
# 12    bleatz      1         3                NaN                   NaN
# 13    bleatz      1         4                NaN                   NaN
# 14    bleatz      1         5                NaN                   NaN
#
#     Type du son (EP,ED,OST) (+1)  Numéro du son (+1)  Auteur du son (+1)  \
# 0                            NaN                 NaN                 NaN
# 1                            NaN                 NaN                 NaN
# 2                            NaN                 NaN                 NaN
# 3                            NaN                 NaN                 NaN
# 4                            NaN                 NaN                 NaN
# 5                            NaN                 NaN                 NaN
# 6                            NaN                 NaN                 NaN
# 7                            NaN                 NaN                 NaN
# 8                            NaN                 NaN                 NaN
# 9                            NaN                 NaN                 NaN
# 10                           NaN                 NaN                 NaN
# 11                           NaN                 NaN                 NaN
# 12                           NaN                 NaN                 NaN
# 13                           NaN                 NaN                 NaN
# 14                           NaN                 NaN                 NaN
#
#     Points  Total
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# 5      NaN    NaN
# 6      NaN    NaN
# 7      NaN    NaN
# 8      NaN    NaN
# 9      NaN    NaN
# 10     NaN    NaN
# 11     NaN    NaN
# 12     NaN    NaN
# 13     NaN    NaN
# 14     NaN    NaN

# %%
msg_01_clean
msg_01_clean
# Out:
# ['unravel', 'tokyo ghoul', 'op', '1', 'toru kitajima']

# %%
tot = 0
for elem in msg_01_clean:
    
    distance, ratio = levCalclulate(elem, bdd_01_lower.iloc[0][3]) # nom du son
    if (distance <= 3) and (ratio > 0.8):
        print("Nom de l'oeuvre :", elem, " (+3 pts)")
        tot += 3
    
    distance, ratio = levCalclulate(elem, bdd_01_lower.iloc[0][4]) # nom de l'oeuvre
    if (distance <= 3) and (ratio > 0.8):
        print("Titre du son :", elem, " (+1 pts)")
        tot += 1
    
    distance, ratio = levCalclulate(elem, bdd_01_lower.iloc[0][5]) # OP/ED/OST
    if (distance <= 3) and (ratio > 0.8):
        print("Type du son (EP,ED,OST) :", elem, " (+1 pts)")
        tot += 1

    distance, ratio = levCalclulate(elem, bdd_01_lower.iloc[0][6]) # Numéro
    if (distance <= 3) and (ratio > 0.8):
        print("Numéro du son :", elem, " (+1 pts)")
        tot += 1

    distance, ratio = levCalclulate(elem, bdd_01_lower.iloc[0][7]) # Auteur
    if (distance <= 3) and (ratio > 0.8):
        print("Auteur du son :", elem, " (+1 pts)")
        tot += 1

print("Total : ",tot,"/ 7 pts")
# Out:
# Nom de l'oeuvre : unravel  (+3 pts)
# Titre du son : tokyo ghoul  (+1 pts)
# Type du son (EP,ED,OST) : op  (+1 pts)
# Numéro du son : 1  (+1 pts)
# Auteur du son : toru kitajima  (+1 pts)
# Total :  7 / 7 pts

# %%
print(bdd_01_lower.iloc[0][3])
print(bdd_01_lower.iloc[0][4])
print(bdd_01_lower.iloc[0][5])
print(bdd_01_lower.iloc[0][6])
print(bdd_01_lower.iloc[0][7])
# Out:
# unravel
# tokyo ghoul
# op
# 1
# toru kitajima
